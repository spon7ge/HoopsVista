# %%
import pandas as pd
import numpy as np
import os
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.metrics import mean_squared_error, r2_score
from xgboost import XGBRegressor
import joblib  # For saving the model

# %% [markdown]
# ### Load DATA

# %%
pd.set_option('display.max_columns', None)

# Load the data
csv_file_path = os.path.join('..', 'Data', 'csv_file', 'combined_data', 'combined_AST_df.csv')
train_data = pd.read_csv(csv_file_path)
print(train_data.columns.tolist())
train_data.tail()
# Out:
# ['PLAYER_NAME', 'PLAYER_ID', 'MATCHUP', 'TEAM', 'TEAM_ID', 'OPPONENT', 'GAME_ID', 'GAME_DATE', 'WL', 'MIN', 'PTS', 'AST', 'REB', 'FGM', 'FGA', 'FG_PCT', 'FG3M', 'FG3A', 'FG3_PCT', 'FTM', 'FTA', 'FT_PCT', 'OREB', 'DREB', 'STL', 'BLK', 'TOV', 'PF', 'PLUS_MINUS', 'FANTASY_PTS', 'OFF_RATING', 'DEF_RATING', 'NET_RATING', 'AST_PCT', 'AST_TOV', 'USG_PCT', 'TS_PCT', 'E_PACE', 'TEAM_MIN', 'TEAM_FGM', 'TEAM_FGA', 'TEAM_FG_PCT', 'TEAM_FG3M', 'TEAM_FG3A', 'TEAM_FG3_PCT', 'TEAM_FTM', 'TEAM_FTA', 'TEAM_FT_PCT', 'TEAM_OREB', 'TEAM_DREB', 'TEAM_REB', 'TEAM_AST', 'TEAM_STL', 'TEAM_BLK', 'TEAM_TOV', 'TEAM_PF', 'TEAM_PTS', 'OPP_DEF_RATING', 'OPP_STL', 'OPP_BLK', 'OPP_REB', 'OPP_TEAM_ID', 'TEAM_OFF_RATING', 'TEAM_PACE', 'GAME_PACE', 'OPP_PACE', 'PER', 'HOME_GAME', 'USG_PCT_LAST_5', 'USG_DRTG_INTERACTION', 'PLAYER_HOME_AVG_AST', 'PLAYER_AWAY_AVG_AST', 'AST_LAST_3', 'AST_LAST_5', 'AST_LAST_7']
#         PLAYER_NAME  PLAYER_ID      MATCHUP TEAM     TEAM_ID OPPONENT  \
# 97376  Xavier Cooks    1641645    WAS @ NYK  WAS  1610612764      NYK
# 97377  Xavier Cooks    1641645  WAS vs. MIL  WAS  1610612764      MIL
# 97378  Xavier Cooks    1641645    WAS @ ATL  WAS  1610612764      ATL
# 97379  Xavier Cooks    1641645  WAS vs. MIA  WAS  1610612764      MIA
# 97380  Xavier Cooks    1641645  WAS vs. HOU  WAS  1610612764      HOU
#
#         GAME_ID   GAME_DATE WL   MIN  PTS  AST  REB  FGM  FGA  FG_PCT  FG3M  \
# 97376  22201168  2023-04-02  L   4.0    0    1    1    0    0     NaN     0
# 97377  22201179  2023-04-04  L  26.0    8    1    2    4    5   0.800     0
# 97378  22201191  2023-04-05  L  17.0    6    3    6    2    5   0.400     0
# 97379  22201204  2023-04-07  W  22.0   10    0    9    4    5   0.800     0
# 97380  22201222  2023-04-09  L  38.0   10    0   14    5   11   0.455     0
#
#        FG3A  FG3_PCT  FTM  FTA  FT_PCT  OREB  DREB  STL  BLK  TOV  PF  \
# 97376     0      NaN    0    0     NaN     0     1    0    1    0   1
# 97377     0      NaN    0    0     NaN     0     2    0    0    2   3
# 97378     0      NaN    2    2   1.000     2     4    1    1    1   3
# 97379     1      0.0    2    6   0.333     4     5    3    0    1   3
# 97380     0      NaN    0    2   0.000     7     7    2    2    1   2
#
#        PLUS_MINUS  FANTASY_PTS  OFF_RATING  DEF_RATING  NET_RATING  AST_PCT  \
# 97376           9          5.7       166.7        66.7       100.0    0.167
# 97377           5          9.9       133.3       123.0        10.4    0.040
# 97378           2         22.7       112.5       107.5         5.0    0.188
# 97379         -22         28.8        84.9       128.8       -43.9    0.000
# 97380           3         37.8       112.3       106.0         6.3    0.000
#
#        AST_TOV  USG_PCT  TS_PCT  E_PACE  TEAM_MIN  TEAM_FGM  TEAM_FGA  \
# 97376      0.0    0.000   0.000  121.21       240        39        79
# 97377      0.5    0.108   0.800  111.49       240        50        99
# 97378      3.0    0.159   0.510  111.85       240        45        94
# 97379      0.0    0.145   0.654  115.07       240        39        84
# 97380      0.0    0.138   0.421  101.35       240        41        97
#
#        TEAM_FG_PCT  TEAM_FG3M  TEAM_FG3A  TEAM_FG3_PCT  TEAM_FTM  TEAM_FTA  \
# 97376        0.494         16         37         0.432        15        18
# 97377        0.505         13         27         0.481        15        21
# 97378        0.479          6         28         0.214        20        26
# 97379        0.464          7         33         0.212        29        37
# 97380        0.423         14         45         0.311        13        21
#
#        TEAM_FT_PCT  TEAM_OREB  TEAM_DREB  TEAM_REB  TEAM_AST  TEAM_STL  \
# 97376        0.833          5         33        38        26         9
# 97377        0.714          9         33        42        30         7
# 97378        0.769         12         27        39        23        10
# 97379        0.784         12         38        50        23         4
# 97380        0.619         14         37        51        28        11
#
#        TEAM_BLK  TEAM_TOV  TEAM_PF  TEAM_PTS  OPP_DEF_RATING  OPP_STL  \
# 97376         5        18       18       109      109.087270     12.0
# 97377         4         9       21       128      118.255728      6.0
# 97378         9        14       26       116      107.967238     10.0
# 97379         3        16       18       114      109.321059      7.0
# 97380         5        12       21       109      104.566385      8.0
#
#        OPP_BLK  OPP_REB   OPP_TEAM_ID  TEAM_OFF_RATING  TEAM_PACE  GAME_PACE  \
# 97376      4.0     39.0  1.610613e+09       109.087270      99.92      99.92
# 97377      7.0     56.0  1.610613e+09       118.255728     108.24     109.50
# 97378      5.0     48.0  1.610613e+09       107.967238     107.44     106.52
# 97379      4.0     47.0  1.610613e+09       109.321059     104.28     104.78
# 97380      6.0     51.0  1.610613e+09       104.566385     104.24     104.28
#
#        OPP_PACE        PER  HOME_GAME  USG_PCT_LAST_5  USG_DRTG_INTERACTION  \
# 97376     99.92  26.918250          0          0.0952              0.000000
# 97377    110.76  13.926000          1          0.1168             12.771619
# 97378    105.60  38.184235          0          0.1486             17.166791
# 97379    105.28  40.381273          1          0.1110             15.851554
# 97380    104.32  29.906368          1          0.1100             14.430161
#
#        PLAYER_HOME_AVG_AST  PLAYER_AWAY_AVG_AST  AST_LAST_3  AST_LAST_5  \
# 97376             0.000000             1.000000    0.333333         0.4
# 97377             0.200000             1.000000    0.666667         0.6
# 97378             0.200000             1.666667    1.666667         1.0
# 97379             0.166667             1.666667    1.333333         1.0
# 97380             0.142857             1.666667    1.000000         1.0
#
#        AST_LAST_7
# 97376    0.333333
# 97377    0.428571
# 97378    0.857143
# 97379    0.857143
# 97380    0.714286

# %%
features = [
    'MIN','AST_PCT', 'AST_TOV','USG_PCT', 'TS_PCT', 'PER', 'AST_LAST_3','AST_LAST_5', 'AST_LAST_7',
    'OFF_RATING', 'PLAYER_HOME_AVG_AST', 'PLAYER_AWAY_AVG_AST',
    'TEAM_AST', 'TEAM_PACE','OPP_DEF_RATING', 'OPP_STL', 'OPP_PACE', 'HOME_GAME',
]

X_train = train_data[features]
y_train = train_data['AST']

# Initialize and train the XGBRegressor
xgb_model_reb = XGBRegressor(random_state=0)
xgb_model_reb.fit(X_train, y_train)

# Evaluate the model using cross-validation on the training data
cv_scores = cross_val_score(xgb_model_reb, X_train, y_train, cv=5, scoring='neg_mean_squared_error')
rmse_scores = np.sqrt(-cv_scores)
print(f"Cross-validated RMSE: {rmse_scores.mean():.4f} ± {rmse_scores.std():.4f}")

# Load the test data (2024)
test_csv_file_path = os.path.join('..', 'Data', 'csv_file', '2024', 'players_AST_df_2024.csv')
test_data = pd.read_csv(test_csv_file_path)

# Ensure the test data has the same features
X_test = test_data[features]
y_test = test_data['AST']

# Make predictions on the 2024 data
predictions_2024 = xgb_model_reb.predict(X_test)

# Evaluate the model's performance on the 2024 data
rmse_2024 = np.sqrt(mean_squared_error(y_test, predictions_2024))
r2_2024 = r2_score(y_test, predictions_2024)
print(f"2024 Season RMSE: {rmse_2024:.4f}, R²: {r2_2024:.4f}")

# Add predictions to the 2024 data for comparison
test_data['actual'] = y_test
test_data['predicted'] = predictions_2024
test_data['error'] = abs(y_test-predictions_2024).round(2)
# Out:
# Cross-validated RMSE: 0.3643 ± 0.0148
# 2024 Season RMSE: 0.3678, R²: 0.9809

# %%
# test_data[['PLAYER_NAME','actual','predicted','error']]
anthony_davis_results = test_data[test_data['PLAYER_NAME'] == 'Draymond Green']
anthony_davis_results[['PLAYER_NAME','actual','predicted','error']].tail(20)
# Out:
#          PLAYER_NAME  actual  predicted  error
# 3124  Draymond Green       2   1.843168   0.16
# 3125  Draymond Green       6   5.799906   0.20
# 3126  Draymond Green      12  11.575361   0.42
# 3127  Draymond Green       4   3.435007   0.56
# 3128  Draymond Green       4   3.496260   0.50
# 3129  Draymond Green      13  12.197504   0.80
# 3130  Draymond Green       5   5.463938   0.46
# 3131  Draymond Green       7   7.038715   0.04
# 3132  Draymond Green       6   5.329205   0.67
# 3133  Draymond Green       3   3.792159   0.79
# 3134  Draymond Green       8   7.034459   0.97
# 3135  Draymond Green       1   1.123221   0.12
# 3136  Draymond Green       4   3.722842   0.28
# 3137  Draymond Green      11   9.314138   1.69
# 3138  Draymond Green       6   5.479085   0.52
# 3139  Draymond Green       5   5.164996   0.16
# 3140  Draymond Green       3   2.878677   0.12
# 3141  Draymond Green       3   2.602728   0.40
# 3142  Draymond Green      10   9.015695   0.98
# 3143  Draymond Green      11  11.137025   0.14

# %%
test_data[['actual','predicted','error']].describe()
# Out:
#              actual     predicted         error
# count  26401.000000  26401.000000  26401.000000
# mean       2.485133      2.494070      0.206752
# std        2.662964      2.656201      0.304184
# min        0.000000     -0.597291      0.000000
# 25%        0.000000      0.063474      0.020000
# 50%        2.000000      1.844934      0.080000
# 75%        4.000000      3.717601      0.270000
# max       23.000000     19.546095      3.500000

# %%
import matplotlib.pyplot as plt
import xgboost as xgb

xgb.plot_importance(xgb_model_reb)
plt.show()

# %%
joblib.dump(xgb_model_reb, 'xgb_model_ast.pkl')
# Out:
# ['xgb_model_ast.pkl']
