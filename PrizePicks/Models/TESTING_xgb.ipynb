# %%
import pandas as pd
import numpy as np
import os
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import mean_squared_error, r2_score
from xgboost import XGBRegressor
import joblib  # For saving the model

# %% [markdown]
# ### Load DATA

# %%
pd.set_option('display.max_columns', None)

# Load the data
csv_file_path = os.path.join('..', 'Data', 'csv_file', 'combined_data', 'train_data.csv')
train_data = pd.read_csv(csv_file_path)
train_data.tail()
# Out:
#         PLAYER_NAME  PLAYER_ID      MATCHUP TEAM     TEAM_ID OPPONENT  \
# 97376  Xavier Cooks    1641645    WAS @ NYK  WAS  1610612764      NYK
# 97377  Xavier Cooks    1641645  WAS vs. MIL  WAS  1610612764      MIL
# 97378  Xavier Cooks    1641645    WAS @ ATL  WAS  1610612764      ATL
# 97379  Xavier Cooks    1641645  WAS vs. MIA  WAS  1610612764      MIA
# 97380  Xavier Cooks    1641645  WAS vs. HOU  WAS  1610612764      HOU
#
#         GAME_ID   GAME_DATE WL   MIN  PTS  AST  REB  FGM  FGA  FG_PCT  FG3M  \
# 97376  22201168  2023-04-02  L   4.0    0    1    1    0    0     NaN     0
# 97377  22201179  2023-04-04  L  26.0    8    1    2    4    5   0.800     0
# 97378  22201191  2023-04-05  L  17.0    6    3    6    2    5   0.400     0
# 97379  22201204  2023-04-07  W  22.0   10    0    9    4    5   0.800     0
# 97380  22201222  2023-04-09  L  38.0   10    0   14    5   11   0.455     0
#
#        FG3A  FG3_PCT  FTM  FTA  FT_PCT  OREB  DREB  STL  BLK  TOV  PF  \
# 97376     0      NaN    0    0     NaN     0     1    0    1    0   1
# 97377     0      NaN    0    0     NaN     0     2    0    0    2   3
# 97378     0      NaN    2    2   1.000     2     4    1    1    1   3
# 97379     1      0.0    2    6   0.333     4     5    3    0    1   3
# 97380     0      NaN    0    2   0.000     7     7    2    2    1   2
#
#        PLUS_MINUS  FANTASY_PTS  OFF_RATING  DEF_RATING  NET_RATING  AST_PCT  \
# 97376           9          5.7       166.7        66.7       100.0    0.167
# 97377           5          9.9       133.3       123.0        10.4    0.040
# 97378           2         22.7       112.5       107.5         5.0    0.188
# 97379         -22         28.8        84.9       128.8       -43.9    0.000
# 97380           3         37.8       112.3       106.0         6.3    0.000
#
#        AST_TOV  USG_PCT  TS_PCT  E_PACE  TEAM_MIN  TEAM_FGM  TEAM_FGA  \
# 97376      0.0    0.000   0.000  121.21       240        39        79
# 97377      0.5    0.108   0.800  111.49       240        50        99
# 97378      3.0    0.159   0.510  111.85       240        45        94
# 97379      0.0    0.145   0.654  115.07       240        39        84
# 97380      0.0    0.138   0.421  101.35       240        41        97
#
#        TEAM_FG_PCT  TEAM_FG3M  TEAM_FG3A  TEAM_FG3_PCT  TEAM_FTM  TEAM_FTA  \
# 97376        0.494         16         37         0.432        15        18
# 97377        0.505         13         27         0.481        15        21
# 97378        0.479          6         28         0.214        20        26
# 97379        0.464          7         33         0.212        29        37
# 97380        0.423         14         45         0.311        13        21
#
#        TEAM_FT_PCT  TEAM_OREB  TEAM_DREB  TEAM_REB  TEAM_AST  TEAM_STL  \
# 97376        0.833          5         33        38        26         9
# 97377        0.714          9         33        42        30         7
# 97378        0.769         12         27        39        23        10
# 97379        0.784         12         38        50        23         4
# 97380        0.619         14         37        51        28        11
#
#        TEAM_BLK  TEAM_TOV  TEAM_PF  TEAM_PTS  OPP_DEF_RATING  OPP_STL  \
# 97376         5        18       18       109      109.087270     12.0
# 97377         4         9       21       128      118.255728      6.0
# 97378         9        14       26       116      107.967238     10.0
# 97379         3        16       18       114      109.321059      7.0
# 97380         5        12       21       109      104.566385      8.0
#
#        OPP_BLK  OPP_REB  OPP_TEAM_ID  TEAM_OFF_RATING  TEAM_PACE  GAME_PACE  \
# 97376      4.0     39.0   1610612752       109.087270      99.92      99.92
# 97377      7.0     56.0   1610612749       118.255728     108.24     109.50
# 97378      5.0     48.0   1610612737       107.967238     107.44     106.52
# 97379      4.0     47.0   1610612748       109.321059     104.28     104.78
# 97380      6.0     51.0   1610612745       104.566385     104.24     104.28
#
#        OPP_PACE        PER  HOME_GAME  USG_PCT_LAST_5  USG_DRTG_INTERACTION  \
# 97376     99.92  26.918250          0          0.0952              0.000000
# 97377    110.76  13.926000          1          0.1168             12.771619
# 97378    105.60  38.184235          0          0.1486             17.166791
# 97379    105.28  40.381273          1          0.1110             15.851554
# 97380    104.32  29.906368          1          0.1100             14.430161
#
#        PTS_LAST_5  REB_LAST_5  AST_LAST_5  STL_LAST_5  BLK_LAST_5  \
# 97376         0.8         1.0         0.4         0.0         0.2
# 97377         2.4         1.2         0.6         0.0         0.2
# 97378         3.6         2.2         1.0         0.2         0.4
# 97379         5.2         4.0         1.0         0.8         0.4
# 97380         6.8         6.4         1.0         1.2         0.8
#
#        PTS+AST_LAST_5  PTS+REB_LAST_5  PTS+REB+AST_LAST_5  REB+AST_LAST_5  \
# 97376             1.2             1.8                 2.2             1.4
# 97377             3.0             3.6                 4.2             1.8
# 97378             4.6             5.8                 6.8             3.2
# 97379             6.2             9.2                10.2             5.0
# 97380             7.8            13.2                14.2             7.4
#
#        STL+BLK_LAST_5  PLAYER_HOME_AVG_PTS  PLAYER_HOME_AVG_REB  \
# 97376             0.2             1.000000             1.250000
# 97377             0.2             2.400000             1.400000
# 97378             0.6             2.400000             1.400000
# 97379             1.2             3.666667             2.666667
# 97380             2.0             4.571429             4.285714
#
#        PLAYER_HOME_AVG_AST  PLAYER_HOME_AVG_STL  PLAYER_HOME_AVG_BLK  \
# 97376             0.000000             0.000000             0.000000
# 97377             0.200000             0.000000             0.000000
# 97378             0.200000             0.000000             0.000000
# 97379             0.166667             0.500000             0.000000
# 97380             0.142857             0.714286             0.285714
#
#        PLAYER_HOME_AVG_PTS_AST  PLAYER_HOME_AVG_PTS_AST_REB  \
# 97376                 1.000000                         2.25
# 97377                 2.600000                         4.00
# 97378                 2.600000                         4.00
# 97379                 3.833333                         6.50
# 97380                 4.714286                         9.00
#
#        PLAYER_HOME_AVG_AST_REB  PLAYER_HOME_AVG_PTS_REB  \
# 97376                 1.250000                 2.250000
# 97377                 1.600000                 3.800000
# 97378                 1.600000                 3.800000
# 97379                 2.833333                 6.333333
# 97380                 4.428571                 8.857143
#
#        PLAYER_HOME_AVG_STL_BLK  PLAYER_AWAY_AVG_PTS  PLAYER_AWAY_AVG_REB  \
# 97376                      0.0                  0.0             1.000000
# 97377                      0.0                  0.0             1.000000
# 97378                      0.0                  2.0             2.666667
# 97379                      0.5                  2.0             2.666667
# 97380                      1.0                  2.0             2.666667
#
#        PLAYER_AWAY_AVG_AST  PLAYER_AWAY_AVG_STL  PLAYER_AWAY_AVG_BLK  \
# 97376             1.000000             0.000000             0.500000
# 97377             1.000000             0.000000             0.500000
# 97378             1.666667             0.333333             0.666667
# 97379             1.666667             0.333333             0.666667
# 97380             1.666667             0.333333             0.666667
#
#        PLAYER_AWAY_AVG_PTS_AST  PLAYER_AWAY_AVG_PTS_AST_REB  \
# 97376                 1.000000                     2.000000
# 97377                 1.000000                     2.000000
# 97378                 3.666667                     6.333333
# 97379                 3.666667                     6.333333
# 97380                 3.666667                     6.333333
#
#        PLAYER_AWAY_AVG_AST_REB  PLAYER_AWAY_AVG_PTS_REB  \
# 97376                 2.000000                 1.000000
# 97377                 2.000000                 1.000000
# 97378                 4.333333                 4.666667
# 97379                 4.333333                 4.666667
# 97380                 4.333333                 4.666667
#
#        PLAYER_AWAY_AVG_STL_BLK  PTS_LAST_3  PTS_LAST_7
# 97376                      0.5    1.333333    0.666667
# 97377                      0.5    3.333333    1.714286
# 97378                      1.0    4.666667    2.571429
# 97379                      1.0    8.000000    4.000000
# 97380                      1.0    8.666667    5.428571

# %%
# Define features and target
features = [
    'MIN', 'FG_PCT', 'FG3_PCT', 'FT_PCT', 'PTS_LAST_3', 'PTS_LAST_5', 'PTS_LAST_7',
    'PLAYER_HOME_AVG_PTS', 'PLAYER_AWAY_AVG_PTS', 'USG_PCT', 'PER', 'TS_PCT',
    'USG_PCT_LAST_5', 'USG_DRTG_INTERACTION', 'NET_RATING', 'OFF_RATING', 'PF',
    'TEAM_OFF_RATING', 'TEAM_PACE', 'TEAM_PTS', 'TEAM_AST', 'TEAM_FGA',
    'OPP_DEF_RATING', 'OPP_PACE', 'GAME_PACE', 'HOME_GAME'
]

X_train = train_data[features]
y_train = train_data['PTS']

# Initialize and train the XGBRegressor
xgb_model = XGBRegressor()
xgb_model.fit(X_train, y_train)

# Evaluate the model using cross-validation on the training data
cv_scores = cross_val_score(xgb_model, X_train, y_train, cv=5, scoring='neg_mean_squared_error')
rmse_scores = np.sqrt(-cv_scores)
print(f"Cross-validated RMSE: {rmse_scores.mean():.4f} ± {rmse_scores.std():.4f}")

# Load the test data (2024)
test_csv_file_path = os.path.join('..', 'Data', 'csv_file', '2024', 'players_df_2024.csv')
test_data = pd.read_csv(test_csv_file_path)

# Ensure the test data has the same features
X_test = test_data[features]
y_test = test_data['PTS']

# Make predictions on the 2024 data
predictions_2024 = xgb_model.predict(X_test)

# Evaluate the model's performance on the 2024 data
rmse_2024 = np.sqrt(mean_squared_error(y_test, predictions_2024))
r2_2024 = r2_score(y_test, predictions_2024)
print(f"2024 Season RMSE: {rmse_2024:.4f}, R²: {r2_2024:.4f}")

# Add predictions to the 2024 data for comparison
test_data['actual'] = y_test
test_data['predicted'] = predictions_2024
test_data['error'] = abs(y_test-predictions_2024)

# Optionally, save the results or further analyze them
# test_data.to_csv('predictions_2024.csv', index=False)
# Out:
# Cross-validated RMSE: 1.3437 ± 0.0158
# 2024 Season RMSE: 1.3080, R²: 0.9788

# %%
test_data[['PLAYER_NAME','actual','predicted','error']].head(20)
# Out:
#      PLAYER_NAME  actual  predicted     error
# 0   LeBron James      21  18.252399  2.747601
# 1   LeBron James      21  20.858248  0.141752
# 2   LeBron James      27  33.722885  6.722885
# 3   LeBron James      19  20.817547  1.817547
# 4   LeBron James      35  35.797432  0.797432
# 5   LeBron James      24  26.766809  2.766809
# 6   LeBron James      30  27.662943  2.337057
# 7   LeBron James      18  20.893169  2.893169
# 8   LeBron James      32  34.796825  2.796825
# 9   LeBron James      16  18.244968  2.244968
# 10  LeBron James      28  31.225863  3.225863
# 11  LeBron James      35  34.069481  0.930519
# 12  LeBron James      37  36.246311  0.753689
# 13  LeBron James      17  20.494562  3.494562
# 14  LeBron James      26  26.463152  0.463152
# 15  LeBron James      22  21.329067  0.670933
# 16  LeBron James      18  15.993508  2.006492
# 17  LeBron James      25  24.170153  0.829847
# 18  LeBron James      21  24.378584  3.378584
# 19  LeBron James      16  17.529095  1.529095

# %%
results_df.describe()
# Out:
#              Actual     Predicted         Error
# count  26401.000000  26401.000000  26401.000000
# mean      10.642021     10.639983      0.937564
# std        8.983887      8.906435      0.979508
# min        0.000000     -4.872216      0.000012
# 25%        3.000000      3.465735      0.211056
# 50%        9.000000      8.803712      0.640827
# 75%       16.000000     15.755449      1.349043
# max       73.000000     62.852348     14.702698
