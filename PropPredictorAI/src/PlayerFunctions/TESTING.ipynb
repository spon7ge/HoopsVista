# %%
import pandas as pd
import numpy as np
from nba_api.stats.endpoints import teamgamelog, boxscoreadvancedv2, leaguedashplayerstats, playercareerstats, playergamelog, commonplayerinfo, playerdashboardbygeneralsplits,leaguegamelog, leaguedashteamstats,teamdashboardbygeneralsplits
from nba_api.stats.static import players,teams
from fetch_player_data import *
from fetch_team_data import *
from features import *

# %% [markdown]
# ## Gather Data and explore it

# %%
import os
import pandas as pd

# Load and process data for 2020
csv_file_path = os.path.join('..','..','Data', 'csv_file', '2020', 'players_clean_df_2020.csv')
player_data_2020 = pd.read_csv(csv_file_path)

# Load and process data for 2021
csv_file_path = os.path.join('..', '..','Data', 'csv_file', '2021', 'players_clean_df_2021.csv')
player_data_2021 = pd.read_csv(csv_file_path)

# Load and process data for 2022
csv_file_path = os.path.join('..','..', 'Data', 'csv_file', '2022', 'players_clean_df_2022.csv')
player_data_2022 = pd.read_csv(csv_file_path)

# Load and process data for 2023
csv_file_path = os.path.join('..','..', 'Data', 'csv_file', '2023', 'players_clean_df_2023.csv')
player_data_2023 = pd.read_csv(csv_file_path)

# Load and process data for 2024
csv_file_path = os.path.join('..','..', 'Data', 'csv_file', '2024', 'players_clean_df_2024.csv')
player_data_2024 = pd.read_csv(csv_file_path)

# Concatenate all seasons' data
seasons_concat = pd.concat([player_data_2020, player_data_2021, player_data_2022, player_data_2023,player_data_2024], ignore_index=True)

# %%
csv_file_path = os.path.join('..','..','Data', 'csv_file', 'combined_data', 'trained_final_df_.csv')
player_data = pd.read_csv(csv_file_path)
player_data.head()
# Out:
#                 PLAYER_NAME  PLAYER_ID      MATCHUP TEAM     TEAM_ID OPPONENT  \
# 0                Quinn Cook    1626188    LAL @ LAC  LAL  1610612747      LAC
# 1              Troy Daniels     203584    LAL @ LAC  LAL  1610612747      LAC
# 2          Patrick Beverley     201976  LAC vs. LAL  LAC  1610612746      LAL
# 3             Avery Bradley     202340    LAL @ LAC  LAL  1610612747      LAC
# 4  Kentavious Caldwell-Pope     203484    LAL @ LAC  LAL  1610612747      LAC
#
#     GAME_ID   GAME_DATE WL   MIN  ...  OPP_REB   OPP_TEAM_ID  TEAM_OFF_RATING  \
# 0  21900002  2019-10-22  L  17.0  ...     45.0  1.610613e+09       102.781137
# 1  21900002  2019-10-22  L  16.0  ...     45.0  1.610613e+09       102.781137
# 2  21900002  2019-10-22  W  31.0  ...     41.0  1.610613e+09       118.443316
# 3  21900002  2019-10-22  L  24.0  ...     45.0  1.610613e+09       102.781137
# 4  21900002  2019-10-22  L  27.0  ...     45.0  1.610613e+09       102.781137
#
#    TEAM_PACE  GAME_PACE  OPP_PACE        PER  HOME_GAME  USG_PCT_LAST_5  \
# 0      99.24       96.9     94.56  15.481765          0           0.182
# 1      99.24       96.9     94.56  17.180375          0           0.206
# 2      94.56       96.9     99.24  20.163129          1           0.122
# 3      99.24       96.9     94.56  16.008042          0           0.170
# 4      99.24       96.9     94.56   3.850815          0           0.058
#
#    USG_DRTG_INTERACTION
# 0             18.706167
# 1             21.172914
# 2             14.450085
# 3             17.472793
# 4              5.961306
#
# [5 rows x 70 columns]

# %%
player_data = add_BLK_features(player_data)
save_player_stats_to_csv(player_data)
# Out:
# Data saved to /Applications/Documents/PredictorProject/HoopsVista/PropPredictorAI/Data/csv_file/2025/team_df_2025.csv
# '/Applications/Documents/PredictorProject/HoopsVista/PropPredictorAI/Data/csv_file/2025/team_df_2025.csv'

# %%
player_data.head()
# Out:
#        PLAYER_NAME  PLAYER_ID      MATCHUP TEAM     TEAM_ID OPPONENT  \
# 292   Vince Carter       1713    ATL @ DET  ATL  1610612737      DET
# 750   Vince Carter       1713  ATL vs. ORL  ATL  1610612737      ORL
# 958   Vince Carter       1713  ATL vs. PHI  ATL  1610612737      PHI
# 1115  Vince Carter       1713    ATL @ MIA  ATL  1610612737      MIA
# 1434  Vince Carter       1713  ATL vs. MIA  ATL  1610612737      MIA
#
#        GAME_ID   GAME_DATE WL   MIN  ...        PER  HOME_GAME  \
# 292   21900014  2019-10-24  W  10.0  ...  -0.258800          0
# 750   21900028  2019-10-26  W  12.0  ...  21.072000          1
# 958   21900043  2019-10-28  L  11.0  ...  34.360364          1
# 1115  21900052  2019-10-29  L  18.0  ...  17.300667          0
# 1434  21900066  2019-10-31  L  16.0  ...   6.563062          1
#
#       USG_PCT_LAST_5  USG_DRTG_INTERACTION  USG_PCT_LAST_3  BLK_LAST_3  \
# 292         0.143000             16.690942        0.143000         0.0
# 750         0.129000             11.892570        0.129000         0.0
# 958         0.155333             19.287000        0.155333         0.0
# 1115        0.167750             19.017789        0.176000         0.0
# 1434        0.158600             11.900644        0.178333         0.0
#
#       BLK_LAST_5  BLK_LAST_7  PLAYER_HOME_AVG_BLK  PLAYER_AWAY_AVG_BLK
# 292          0.0         0.0                  NaN                  0.0
# 750          0.0         0.0                  0.0                  0.0
# 958          0.0         0.0                  0.0                  0.0
# 1115         0.0         0.0                  0.0                  0.0
# 1434         0.0         0.0                  0.0                  0.0
#
# [5 rows x 76 columns]
