# %%
import pandas as pd
import numpy as np
from nba_api.stats.endpoints import teamgamelog, boxscoreadvancedv2, leaguedashplayerstats, playercareerstats, playergamelog, commonplayerinfo, playerdashboardbygeneralsplits,leaguegamelog, leaguedashteamstats,teamdashboardbygeneralsplits
from nba_api.stats.static import players,teams
from fetch_player_data import *
from fetch_team_data import *
# from features import *

# %%
def prepare_latest_player_and_team_logs(season='2024-25'):
    # Fetch team logs and enhance with opponent stats, offensive ratings, and pace
    team_logs = get_teams_gamelogs(season=season)
    team_logs = add_opponent_stats(team_logs)
    team_logs = add_team_off_rating(team_logs)
    team_logs = add_pace_stats(team_logs)

    # Fetch player logs and add advanced stats
    player_logs = fetch_and_process_player_stats(season=season).head(100)
    advanced_stats = add_advanced_stats_for_player_games(player_logs).head(100)
    player_logs = merge_player_stats_with_advanced_data(player_logs, advanced_stats)

    # Merge player logs with team logs
    combined_logs = merge_player_with_team(player_logs, team_logs)
    
    return combined_logs

# %%
# data = prepare_latest_player_and_team_logs(season='2015-16')
# data.head()
data = prepare_latest_player_and_team_logs(season='2015-16')
# Out:
# Processing team 1/30: Atlanta Hawks
# Processing team 2/30: Boston Celtics
# Processing team 3/30: Cleveland Cavaliers
# Processing team 4/30: New Orleans Pelicans
# Processing team 5/30: Chicago Bulls
# Processing team 6/30: Dallas Mavericks
# Processing team 7/30: Denver Nuggets
# Processing team 8/30: Golden State Warriors
# Processing team 9/30: Houston Rockets
# Processing team 10/30: Los Angeles Clippers
# Processing team 11/30: Los Angeles Lakers
# Processing team 12/30: Miami Heat
# Processing team 13/30: Milwaukee Bucks
# Processing team 14/30: Minnesota Timberwolves
# Processing team 15/30: Brooklyn Nets
# Processing team 16/30: New York Knicks
# Processing team 17/30: Orlando Magic
# Processing team 18/30: Indiana Pacers
# Processing team 19/30: Philadelphia 76ers
# Processing team 20/30: Phoenix Suns
# Processing team 21/30: Portland Trail Blazers
# Processing team 22/30: Sacramento Kings
# Processing team 23/30: San Antonio Spurs
# ...

# %%
data
# Out:
# (100, 67)

# %% [markdown]
# ## Gather Data and explore it

# %%
# csv_file_path = os.path.join('..', 'Data', 'csv_file','2020', 'teams_df_2020.csv')
# team_data_2020 = pd.read_csv(csv_file_path)

# csv_file_path = os.path.join('..', 'Data', 'csv_file','2021', 'teams_df_2021.csv')
# team_data_2021 = pd.read_csv(csv_file_path)

# csv_file_path = os.path.join('..', 'Data', 'csv_file','2022', 'teams_df_2022.csv')
# team_data_2022 = pd.read_csv(csv_file_path)

# csv_file_path = os.path.join('..', 'Data', 'csv_file','2023', 'teams_df_2023.csv')
# team_data_2023 = pd.read_csv(csv_file_path)

# csv_file_path = os.path.join('..', 'Data', 'csv_file','2024', 'teams_df_2024.csv')
# team_data_2024 = pd.read_csv(csv_file_path)

# %%
# team_data = get_teams_gamelogs(season='2019-20')
# def grab_team_stats(team_data):
#     team_data = add_opponent_stats(team_data)
#     team_data = add_team_off_rating(team_data)
#     team_data = add_pace_stats(team_data)
#     team_data['OPP_TEAM_ID'] = team_data['OPP_TEAM_ID'].astype(int)
#     return team_data
# team_data = grab_team_stats(team_data)
# team_data.head()

# %%
player_data = fetch_and_process_player_stats(season='2023-24')
adv_data = add_advanced_stats_for_player_games(player_data)
player_data = merge_player_stats_with_advanced_data(player_data,adv_data)
player_data.head()

# %%
player_data['GAME_ID'] = player_data['GAME_ID'].astype(int)
team_data_2024['GAME_ID'] = team_data_2024['GAME_ID'].astype(int)
player_data = merge_player_with_team(player_data,team_data_2024)

player_PER(player_data)
add_home_away_indicator(player_data)
add_usg_pct_last_5(player_data)
add_usg_drtg_interaction(player_data)
# calculate_days_of_rest(player_data)
# add_back_to_back(player_data)
save_player_stats_to_csv(player_data, season='2024',type='players_clean',where='2024')
# Out:
# Data saved to C:/Users/alexg/OneDrive/Documents/player_predictor/HoopsVista/PrizePicks/Data/csv_file/2024\players_clean_df_2024.csv
# 'C:/Users/alexg/OneDrive/Documents/player_predictor/HoopsVista/PrizePicks/Data/csv_file/2024\\players_clean_df_2024.csv'

# %%
# import os
# import pandas as pd

# # Load and process data for 2020
# csv_file_path = os.path.join('..', 'Data', 'csv_file', '2020', 'players_clean_df_2020.csv')
# player_data_2020 = pd.read_csv(csv_file_path)
# player_data_2020 = add_player_home_avg(player_data_2020, ['AST'])
# player_data_2020 = add_player_away_avg(player_data_2020, ['AST'])
# player_data_2020 = last_5_avg(player_data_2020, player_id_col='PLAYER_ID', props=['AST'], games=3, date_col='GAME_DATE')
# player_data_2020 = last_5_avg(player_data_2020, player_id_col='PLAYER_ID', props=['AST'], games=5, date_col='GAME_DATE')
# player_data_2020 = last_5_avg(player_data_2020, player_id_col='PLAYER_ID', props=['AST'], games=7, date_col='GAME_DATE')

# # Load and process data for 2021
# csv_file_path = os.path.join('..', 'Data', 'csv_file', '2021', 'players_clean_df_2021.csv')
# player_data_2021 = pd.read_csv(csv_file_path)
# player_data_2021 = add_player_home_avg(player_data_2021, ['AST'])
# player_data_2021 = add_player_away_avg(player_data_2021, ['AST'])
# player_data_2021 = last_5_avg(player_data_2021, player_id_col='PLAYER_ID', props=['AST'], games=3, date_col='GAME_DATE')
# player_data_2021 = last_5_avg(player_data_2021, player_id_col='PLAYER_ID', props=['AST'], games=5, date_col='GAME_DATE')
# player_data_2021 = last_5_avg(player_data_2021, player_id_col='PLAYER_ID', props=['AST'], games=7, date_col='GAME_DATE')

# # Load and process data for 2022
# csv_file_path = os.path.join('..', 'Data', 'csv_file', '2022', 'players_clean_df_2022.csv')
# player_data_2022 = pd.read_csv(csv_file_path)
# player_data_2022 = add_player_home_avg(player_data_2022, ['AST'])
# player_data_2022 = add_player_away_avg(player_data_2022, ['AST'])
# player_data_2022 = last_5_avg(player_data_2022, player_id_col='PLAYER_ID', props=['AST'], games=3, date_col='GAME_DATE')
# player_data_2022 = last_5_avg(player_data_2022, player_id_col='PLAYER_ID', props=['AST'], games=5, date_col='GAME_DATE')
# player_data_2022 = last_5_avg(player_data_2022, player_id_col='PLAYER_ID', props=['AST'], games=7, date_col='GAME_DATE')

# # Load and process data for 2023
# csv_file_path = os.path.join('..', 'Data', 'csv_file', '2023', 'players_clean_df_2023.csv')
# player_data_2023 = pd.read_csv(csv_file_path)
# player_data_2023 = add_player_home_avg(player_data_2023, ['AST'])
# player_data_2023 = add_player_away_avg(player_data_2023, ['AST'])
# player_data_2023 = last_5_avg(player_data_2023, player_id_col='PLAYER_ID', props=['AST'], games=3, date_col='GAME_DATE')
# player_data_2023 = last_5_avg(player_data_2023, player_id_col='PLAYER_ID', props=['AST'], games=5, date_col='GAME_DATE')
# player_data_2023 = last_5_avg(player_data_2023, player_id_col='PLAYER_ID', props=['AST'], games=7, date_col='GAME_DATE')

# Load and process data for 2024
csv_file_path = os.path.join('..', 'Data', 'csv_file', '2024', 'players_clean_df_2024.csv')
player_data_2024 = pd.read_csv(csv_file_path)
player_data_2024 = add_player_home_avg(player_data_2024, ['AST'])
player_data_2024 = add_player_away_avg(player_data_2024, ['AST'])
player_data_2024 = last_5_avg(player_data_2024, player_id_col='PLAYER_ID', props=['AST'], games=3, date_col='GAME_DATE')
player_data_2024 = last_5_avg(player_data_2024, player_id_col='PLAYER_ID', props=['AST'], games=5, date_col='GAME_DATE')
player_data_2024 = last_5_avg(player_data_2024, player_id_col='PLAYER_ID', props=['AST'], games=7, date_col='GAME_DATE')

# Concatenate all seasons' data
seasons_concat = pd.concat([player_data_2020, player_data_2021, player_data_2022, player_data_2023], ignore_index=True)

# %%
save_player_stats_to_csv(player_data_2024, season='2024',type='players_AST',where='2024')
# Out:
# Data saved to C:/Users/alexg/OneDrive/Documents/player_predictor/HoopsVista/PrizePicks/Data/csv_file/2024\players_AST_df_2024.csv
# 'C:/Users/alexg/OneDrive/Documents/player_predictor/HoopsVista/PrizePicks/Data/csv_file/2024\\players_AST_df_2024.csv'

# %%
# player_data = add_player_home_avg(player_data,['PTS'])
# player_data = add_player_home_avg(player_data,['REB'])
# player_data = add_player_home_avg(player_data,['AST'])
# player_data = add_player_home_avg(player_data,['STL'])
# player_data = add_player_home_avg(player_data,['BLK'])
# player_data = add_player_home_avg(player_data,['PTS','AST'])
# player_data = add_player_home_avg(player_data,['PTS','AST','REB'])
# player_data = add_player_home_avg(player_data,['AST','REB'])
# player_data = add_player_home_avg(player_data,['PTS','REB'])
# player_data = add_player_home_avg(player_data,['STL','BLK'])


# player_data = add_player_away_avg(player_data,['PTS'])
# player_data = add_player_away_avg(player_data,['REB'])
# player_data = add_player_away_avg(player_data,['AST'])
# player_data = add_player_away_avg(player_data,['STL'])
# player_data = add_player_away_avg(player_data,['BLK'])
# player_data = add_player_away_avg(player_data,['PTS','AST'])
# player_data = add_player_away_avg(player_data,['PTS','AST','REB'])
# player_data = add_player_away_avg(player_data,['AST','REB'])
# player_data = add_player_away_avg(player_data,['PTS','REB'])
# player_data = add_player_away_avg(player_data,['STL','BLK'])
player_data
# Out:
#         PLAYER_NAME  PLAYER_ID      MATCHUP TEAM     TEAM_ID OPPONENT  \
# 0      Vince Carter       1713    ATL @ DET  ATL  1610612737      DET
# 1      Vince Carter       1713  ATL vs. ORL  ATL  1610612737      ORL
# 2      Vince Carter       1713  ATL vs. PHI  ATL  1610612737      PHI
# 3      Vince Carter       1713    ATL @ MIA  ATL  1610612737      MIA
# 4      Vince Carter       1713  ATL vs. MIA  ATL  1610612737      MIA
# ...             ...        ...          ...  ...         ...      ...
# 22388  Juwan Morgan    1629752  UTA vs. SAS  UTA  1610612762      SAS
# 22389   Matt Mooney    1629760  CLE vs. NYK  CLE  1610612739      NYK
# 22390   Matt Mooney    1629760  CLE vs. NOP  CLE  1610612739      NOP
# 22391   Matt Mooney    1629760  CLE vs. UTA  CLE  1610612739      UTA
# 22392   Matt Mooney    1629760    CLE @ CHI  CLE  1610612739      CHI
#
#         GAME_ID   GAME_DATE WL   MIN  ...  PLAYER_AWAY_AVG_PTS  \
# ...

# %%
add_usg_pct_last_5(player_data)
add_usg_drtg_interaction(player_data)
player_data
# Out:
#                     PLAYER_NAME  PLAYER_ID      MATCHUP TEAM     TEAM_ID  \
# 0                    Kyle Lowry     200768  TOR vs. NOP  TOR  1610612761
# 1                 Norman Powell    1626181  TOR vs. NOP  TOR  1610612761
# 2                  Jrue Holiday     201950    NOP @ TOR  NOP  1610612740
# 3                 Jahlil Okafor    1626143    NOP @ TOR  NOP  1610612740
# 4      Nickeil Alexander-Walker    1629638    NOP @ TOR  NOP  1610612740
# ...                         ...        ...          ...  ...         ...
# 22388          Luc Mbah a Moute     201601  HOU vs. PHI  HOU  1610612745
# 22389              Ben McLemore     203463  HOU vs. PHI  HOU  1610612745
# 22390                Alec Burks     202692    PHI @ HOU  PHI  1610612755
# 22391                Al Horford     201143    PHI @ HOU  PHI  1610612755
# 22392         Derrick Jones Jr.    1627884    MIA @ IND  MIA  1610612748
#
#       OPPONENT     GAME_ID  GAME_DATE WL   MIN  ...  OPP_REB  OPP_TEAM_ID  \
# ...

# %%
player_data = last_5_avg(player_data,props=['PTS'])
player_data = last_5_avg(player_data,props=['REB'])
player_data = last_5_avg(player_data,props=['AST'])
player_data = last_5_avg(player_data,props=['STL'])
player_data = last_5_avg(player_data,props=['BLK'])
player_data = last_5_avg(player_data,props=['PTS','AST'])
player_data = last_5_avg(player_data,props=['PTS','REB'])
player_data = last_5_avg(player_data,props=['PTS','REB','AST'])
player_data = last_5_avg(player_data,props=['REB','AST'])
player_data = last_5_avg(player_data,props=['STL','BLK'])
player_data
# Out:
#         PLAYER_NAME  PLAYER_ID      MATCHUP TEAM     TEAM_ID OPPONENT  \
# 328    Vince Carter       1713    ATL @ DET  ATL  1610612737      DET
# 605    Vince Carter       1713  ATL vs. ORL  ATL  1610612737      ORL
# 891    Vince Carter       1713  ATL vs. PHI  ATL  1610612737      PHI
# 1110   Vince Carter       1713    ATL @ MIA  ATL  1610612737      MIA
# 1409   Vince Carter       1713  ATL vs. MIA  ATL  1610612737      MIA
# ...             ...        ...          ...  ...         ...      ...
# 22191  Juwan Morgan    1629752  UTA vs. SAS  UTA  1610612762      SAS
# 13782   Matt Mooney    1629760  CLE vs. NYK  CLE  1610612739      NYK
# 14904   Matt Mooney    1629760  CLE vs. NOP  CLE  1610612739      NOP
# 19160   Matt Mooney    1629760  CLE vs. UTA  CLE  1610612739      UTA
# 20416   Matt Mooney    1629760    CLE @ CHI  CLE  1610612739      CHI
#
#           GAME_ID  GAME_DATE WL   MIN  ...  PTS_LAST_5  REB_LAST_5  \
# ...

# %%
save_player_stats_to_csv(player_data,season='2020',type='players')
# Out:
# Data saved to C:/Users/alexg/OneDrive/Documents/player_predictor/HoopsVista/PrizePicks/Data/csv_file/2025\players_df_2020.csv
# 'C:/Users/alexg/OneDrive/Documents/player_predictor/HoopsVista/PrizePicks/Data/csv_file/2025\\players_df_2020.csv'

# %%
# Load your data frames
csv_file_path_2020 = os.path.join('..', 'Data', 'csv_file', '2020', 'players_df_2020.csv')
player_data_2020 = pd.read_csv(csv_file_path_2020)
player_data_2020 = last_5_avg(player_data_2020, player_id_col='PLAYER_ID', props=['FG3M'], games=3, date_col='GAME_DATE')
player_data_2020 = last_5_avg(player_data_2020, player_id_col='PLAYER_ID', props=['FG3M'], games=5, date_col='GAME_DATE')
player_data_2020 = last_5_avg(player_data_2020, player_id_col='PLAYER_ID', props=['FG3M'], games=7, date_col='GAME_DATE')
player_data_2020 = add_player_home_avg(player_data_2020,['FG3M'])
player_data_2020 = add_player_away_avg(player_data_2020,['FG3M'])

csv_file_path_2021 = os.path.join('..', 'Data', 'csv_file', '2021', 'players_df_2021.csv')
player_data_2021 = pd.read_csv(csv_file_path_2021)
player_data_2021 = last_5_avg(player_data_2021, player_id_col='PLAYER_ID', props=['FG3M'], games=3, date_col='GAME_DATE')
player_data_2021 = last_5_avg(player_data_2021, player_id_col='PLAYER_ID', props=['FG3M'], games=5, date_col='GAME_DATE')
player_data_2021 = last_5_avg(player_data_2021, player_id_col='PLAYER_ID', props=['FG3M'], games=7, date_col='GAME_DATE')
player_data_2021 = add_player_home_avg(player_data_2021,['FG3M'])
player_data_2021 = add_player_away_avg(player_data_2021,['FG3M'])

csv_file_path_2022 = os.path.join('..', 'Data', 'csv_file', '2022', 'players_df_2022.csv')
player_data_2022 = pd.read_csv(csv_file_path_2022)
player_data_2022 = last_5_avg(player_data_2022, player_id_col='PLAYER_ID', props=['FG3M'], games=3, date_col='GAME_DATE')
player_data_2022 = last_5_avg(player_data_2022, player_id_col='PLAYER_ID', props=['FG3M'], games=5, date_col='GAME_DATE')
player_data_2022 = last_5_avg(player_data_2022, player_id_col='PLAYER_ID', props=['FG3M'], games=7, date_col='GAME_DATE')
player_data_2022 = add_player_home_avg(player_data_2022,['FG3M'])
player_data_2022 = add_player_away_avg(player_data_2022,['FG3M'])

csv_file_path_2023 = os.path.join('..', 'Data', 'csv_file', '2023', 'players_df_2023.csv')
player_data_2023 = pd.read_csv(csv_file_path_2023)
player_data_2023 = last_5_avg(player_data_2023, player_id_col='PLAYER_ID', props=['FG3M'], games=3, date_col='GAME_DATE')
player_data_2023 = last_5_avg(player_data_2023, player_id_col='PLAYER_ID', props=['FG3M'], games=5, date_col='GAME_DATE')
player_data_2023 = last_5_avg(player_data_2023, player_id_col='PLAYER_ID', props=['FG3M'], games=7, date_col='GAME_DATE')
player_data_2023 = add_player_home_avg(player_data_2023,['FG3M'])
player_data_2023 = add_player_away_avg(player_data_2023,['FG3M'])

csv_file_path = os.path.join('..', 'Data', 'csv_file', '2024', 'players_df_2024.csv')
player_data_2024 = pd.read_csv(csv_file_path)
player_data_2024 = last_5_avg(player_data_2024, player_id_col='PLAYER_ID', props=['FG3M'], games=3, date_col='GAME_DATE')
player_data_2024 = last_5_avg(player_data_2024, player_id_col='PLAYER_ID', props=['FG3M'], games=5, date_col='GAME_DATE')
player_data_2024 = last_5_avg(player_data_2024, player_id_col='PLAYER_ID', props=['FG3M'], games=7, date_col='GAME_DATE')
player_data_2024 = add_player_home_avg(player_data_2024,['FG3M'])
player_data_2024 = add_player_away_avg(player_data_2024,['FG3M'])

# Concatenate the data frames
train_data = pd.concat([player_data_2020, player_data_2021, player_data_2022, player_data_2023], axis=0, ignore_index=True)

# %%
save_player_stats_to_csv(player_data_2024,season='2024',type='players')
# Out:
# Data saved to C:/Users/alexg/OneDrive/Documents/player_predictor/HoopsVista/PrizePicks/Data/csv_file/2025\players_df_2024.csv
# 'C:/Users/alexg/OneDrive/Documents/player_predictor/HoopsVista/PrizePicks/Data/csv_file/2025\\players_df_2024.csv'

# %%
player_data_2020 = add_player_home_avg(player_data_2020,['FG3M'])
player_data_2020 = add_player_away_avg(player_data_2020,['FG3M'])

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split

def train_PTS_predict_rf(df, target_col='PTS', season_weights=None, test_size=0.2, random_state=42):
    if season_weights is None:
        season_weights = {
            '2023-24': 1.0,
            '2022-23': 0.75,
            '2021-22': 0.5,
            '2020-21': 0.25
        }
    
    # Add a 'weights' column based on the 'Season'
    df['weights'] = df['Season'].map(season_weights)

    # Features for model training
    features = ['MIN', 'FGA', 'FG3A', 'FTA', 'TOV', 'PLUS_MINUS', 'USG_PCT', 'TS_PCT', 'EFG_PCT',
                'OFF_RATING', 'PTS_LAST_5', 'HomeGame', 'DAYS_OF_REST', 'TEAM_PACE', 'GAME_PACE',
                'OPP_PACE', 'OPP_DRTG', 'OPP_STL', 'OPP_BLK', 'OPP_REB', 'PER', 'BACK_TO_BACK',
                'PLAYER_HOME_AVG_PTS', 'PLAYER_AWAY_AVG_PTS', 'USG_PCT_LAST_5', 'USG_DRTG_INTERACTION']
    
    X = df[features]
    y = df[target_col]
    sample_weights = df['weights']

    # Split the data into training and test sets
    X_train, X_test, y_train, y_test, weights_train, weights_test = train_test_split(
        X, y, sample_weights, test_size=test_size, random_state=random_state)
    
    model = RandomForestRegressor(n_estimators=100, random_state=random_state)
    model.fit(X_train, y_train, sample_weight=weights_train)

    y_pred = model.predict(X_test)

    return model, y_pred, y_test

model, y_pred, y_test = train_PTS_predict_rf(combined_season_df)
