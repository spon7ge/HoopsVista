# %%
import pandas as pd
import numpy as np
from nba_api.stats.endpoints import teamgamelog, boxscoreadvancedv2, leaguedashplayerstats, playercareerstats, playergamelog, commonplayerinfo, playerdashboardbygeneralsplits,leaguegamelog, leaguedashteamstats,teamdashboardbygeneralsplits
from nba_api.stats.static import players,teams
from fetch_player_data import *
from fetch_team_data import *
from features import *
from functions_dont_need_anymore import *

# %%
csv_file_path = os.path.join('..','..','Data', 'csv_file', '2024', 'players_PTS_df_2024.csv')
player_data = pd.read_csv(csv_file_path)
player_data.tail()
# Out:
#           PLAYER_NAME  PLAYER_ID      MATCHUP TEAM     TEAM_ID OPPONENT  \
# 26396  Malik Williams    1642013  TOR vs. WAS  TOR  1610612761      WAS
# 26397  Malik Williams    1642013  TOR vs. IND  TOR  1610612761      IND
# 26398  Malik Williams    1642013    TOR @ BKN  TOR  1610612761      BKN
# 26399  Malik Williams    1642013    TOR @ MIA  TOR  1610612761      MIA
# 26400  Malik Williams    1642013    TOR @ MIA  TOR  1610612761      MIA
#
#         GAME_ID   GAME_DATE WL   MIN  ...  OPP_PACE        PER  HOME_GAME  \
# 26396  22301137  2024-04-07  W   5.0  ...    109.20   7.639600          1
# 26397  22301146  2024-04-09  L  14.0  ...    107.12  43.147429          1
# 26398  22301160  2024-04-10  L  24.0  ...     95.56  37.628333          0
# 26399  22301176  2024-04-12  L  19.0  ...     94.12   4.174368          0
# 26400  22301189  2024-04-14  L  11.0  ...    101.36  34.028000          0
#
#        USG_PCT_LAST_5  USG_DRTG_INTERACTION  PLAYER_HOME_AVG_PTS  \
# 26396        0.034667              0.000000                  0.0
# 26397        0.078250             23.909040                  3.0
# 26398        0.101800             20.842369                  3.0
# 26399        0.096000              7.990277                  3.0
# 26400        0.152000             27.404029                  3.0
#
#        PLAYER_AWAY_AVG_PTS  PTS_LAST_3  PTS_LAST_5  PTS_LAST_7
# 26396             0.000000    0.000000         0.0    0.000000
# 26397             0.000000    2.000000         1.5    1.500000
# 26398             2.333333    4.333333         2.6    2.600000
# 26399             1.750000    4.333333         2.6    2.166667
# 26400             2.600000    4.333333         3.8    2.714286
#
# [5 rows x 75 columns]

# %%
calculate_days_of_rest(player_data)
# Out:
#           PLAYER_NAME  PLAYER_ID      MATCHUP TEAM     TEAM_ID OPPONENT  \
# 0        LeBron James       2544    LAL @ DEN  LAL  1610612747      DEN
# 1        LeBron James       2544  LAL vs. PHX  LAL  1610612747      PHX
# 2        LeBron James       2544    LAL @ SAC  LAL  1610612747      SAC
# 3        LeBron James       2544  LAL vs. ORL  LAL  1610612747      ORL
# 4        LeBron James       2544  LAL vs. LAC  LAL  1610612747      LAC
# ...               ...        ...          ...  ...         ...      ...
# 26396  Malik Williams    1642013  TOR vs. WAS  TOR  1610612761      WAS
# 26397  Malik Williams    1642013  TOR vs. IND  TOR  1610612761      IND
# 26398  Malik Williams    1642013    TOR @ BKN  TOR  1610612761      BKN
# 26399  Malik Williams    1642013    TOR @ MIA  TOR  1610612761      MIA
# 26400  Malik Williams    1642013    TOR @ MIA  TOR  1610612761      MIA
#
#         GAME_ID  GAME_DATE WL   MIN  ...        PER  HOME_GAME  \
# 0      22300061 2023-10-24  L  29.0  ...  49.364414          0
# 1      22300076 2023-10-26  W  35.0  ...  48.907114          1
# 2      22300100 2023-10-29  L  39.0  ...  48.609410          0
# 3      22300111 2023-10-30  W  33.0  ...  37.956697          1
# 4      22300127 2023-11-01  W  42.0  ...  55.692476          1
# ...         ...        ... ..   ...  ...        ...        ...
# 26396  22301137 2024-04-07  W   5.0  ...   7.639600          1
# 26397  22301146 2024-04-09  L  14.0  ...  43.147429          1
# 26398  22301160 2024-04-10  L  24.0  ...  37.628333          0
# 26399  22301176 2024-04-12  L  19.0  ...   4.174368          0
# 26400  22301189 2024-04-14  L  11.0  ...  34.028000          0
#
#        USG_PCT_LAST_5  USG_DRTG_INTERACTION  PLAYER_HOME_AVG_PTS  \
# 0            0.225000             24.870868                  NaN
# 1            0.249500             26.155021                 21.0
# 2            0.272667             34.638338                 21.0
# 3            0.285500             34.371497                 20.0
# 4            0.284000             32.605558                 25.0
# ...               ...                   ...                  ...
# 26396        0.034667              0.000000                  0.0
# 26397        0.078250             23.909040                  3.0
# 26398        0.101800             20.842369                  3.0
# 26399        0.096000              7.990277                  3.0
# 26400        0.152000             27.404029                  3.0
#
#        PLAYER_AWAY_AVG_PTS  PTS_LAST_3  PTS_LAST_5  PTS_LAST_7  DAYS_OF_REST
# 0                21.000000   21.000000        21.0   21.000000           NaN
# 1                21.000000   21.000000        21.0   21.000000           2.0
# 2                24.000000   23.000000        23.0   23.000000           3.0
# 3                24.000000   22.333333        22.0   22.000000           1.0
# 4                24.000000   27.000000        24.6   24.600000           2.0
# ...                    ...         ...         ...         ...           ...
# 26396             0.000000    0.000000         0.0    0.000000           2.0
# 26397             0.000000    2.000000         1.5    1.500000           2.0
# 26398             2.333333    4.333333         2.6    2.600000           1.0
# 26399             1.750000    4.333333         2.6    2.166667           2.0
# 26400             2.600000    4.333333         3.8    2.714286           2.0
#
# [26401 rows x 76 columns]
